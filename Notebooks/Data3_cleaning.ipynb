# %%
# Data3 contains an updated version of Data2 including movies after 2005 to 2023.
# Row number indicates how many movies the data contains (+1 row 0)-> 9826
# Dataset url = https://www.kaggle.com/datasets/akashguna/netflix-prize-shows-information/data

# %%
# Main libraries : Pandas, Numpy, bs4
# Libraries for data visualisation : Matplotlib, Seaborn, Plotly

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objs as go

# %%
df3 = "C:/Users/ALEV PC/Desktop/Project/Data/raw/imdb.csv"
df3 = pd.read_csv(df3)
df3.head()
# Out:
#    Unnamed: 0                          title    year            kind  \
# 0           0                Dinosaur Planet  2003.0  tv mini series
# 1           1                      Character  2021.0           movie
# 2           2              Get Up and Dance!  1994.0     video movie
# 3           3  The Rise and Fall of El Chapo  2016.0        tv movie
# 4           4                    Sick - IMDb     NaN             NaN
#
#                                     genre  rating   vote            country  \
# 0  ['Documentary', 'Animation', 'Family']     7.7  474.0  ['United States']
# 1         ['Crime', 'Horror', 'Thriller']     8.3   46.0          ['Japan']
# 2                              ['Family']     8.1   18.0  ['United States']
# 3                         ['Documentary']     6.9   42.0  ['United States']
# 4                            ['Thriller']     NaN    NaN  ['United States']
#
#        language                                               cast  \
# 0   ['English']              ['Christian Slater', 'Scott Sampson']
# 1  ['Japanese']  ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# 2   ['English']  ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 3           NaN                                                NaN
# 4           NaN  ['Marc Menchaca', 'Gideon Adlon', 'Dylan Spray...
#
#             director          composer  \
# 0                NaN               NaN
# 1    ['Akira Nagai']  ['Youki Kojima']
# 2  ['Steve Purcell']               NaN
# 3                NaN               NaN
# 4     ['John Hyams']               NaN
#
#                                               writer  runtime
# 0   ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1  ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...    125.0
# 2                                                NaN     54.0
# 3                                                NaN     85.0
# 4              ['Katelyn Crabb', 'Kevin Williamson']      NaN

# %%
df3.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                          title    year            kind  \
# 0              0                Dinosaur Planet  2003.0  tv mini series
# 1              1                      Character  2021.0           movie
# 2              2              Get Up and Dance!  1994.0     video movie
# 3              3  The Rise and Fall of El Chapo  2016.0        tv movie
# 4              4                    Sick - IMDb     NaN             NaN
# ...          ...                            ...     ...             ...
# 9821        9821            All Monsters Attack  1969.0           movie
# 9822        9822                   Fidel Castro  2005.0         episode
# 9823        9823                          Epoch  2001.0        tv movie
# 9824        9824                    The Company  2003.0           movie
# 9825        9825                       Predator  1987.0           movie
#
#                                               genre  rating      vote  \
# 0            ['Documentary', 'Animation', 'Family']     7.7     474.0
# 1                   ['Crime', 'Horror', 'Thriller']     8.3      46.0
# 2                                        ['Family']     8.1      18.0
# 3                                   ['Documentary']     6.9      42.0
# 4                                      ['Thriller']     NaN       NaN
# ...                                             ...     ...       ...
# 9821             ['Adventure', 'Family', 'Fantasy']     3.9    4384.0
# 9822        ['Documentary', 'Biography', 'History']     6.4      44.0
# 9823                         ['Sci-Fi', 'Thriller']     4.9    2376.0
# 9824                  ['Drama', 'Music', 'Romance']     6.3    6501.0
# 9825  ['Action', 'Adventure', 'Sci-Fi', 'Thriller']     7.8  386850.0
#
#                                              country  \
# 0                                  ['United States']
# 1                                          ['Japan']
# 2                                  ['United States']
# 3                                  ['United States']
# 4                                  ['United States']
# ...                                              ...
# 9821                                       ['Japan']
# 9822                                             NaN
# 9823                               ['United States']
# 9824  ['United States', 'Germany', 'United Kingdom']
# 9825                     ['United States', 'Mexico']
#
#                                language  \
# 0                           ['English']
# 1                          ['Japanese']
# 2                           ['English']
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 9821                       ['Japanese']
# 9822             ['English', 'Spanish']
# 9823                        ['English']
# 9824                        ['English']
# 9825  ['English', 'Spanish', 'Russian']
#
#                                                    cast  \
# 0                 ['Christian Slater', 'Scott Sampson']
# 1     ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# 2     ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 3                                                   NaN
# 4     ['Marc Menchaca', 'Gideon Adlon', 'Dylan Spray...
# ...                                                 ...
# 9821  ['Tomonori Yazaki', 'Hideyo Amamoto', 'Sachio ...
# 9822  ['Rena Baskin', 'Fulgencio Batista', 'James Bl...
# 9823  ['David Keith', 'Stephanie Niznik', "Ryan O'Ne...
# 9824  ['Neve Campbell', 'Malcolm McDowell', 'James F...
# 9825  ['Arnold Schwarzenegger', 'Carl Weathers', 'El...
#
#                                               director            composer  \
# 0                                                  NaN                 NaN
# 1                                      ['Akira Nagai']    ['Youki Kojima']
# 2                                    ['Steve Purcell']                 NaN
# 3                                                  NaN                 NaN
# 4                                       ['John Hyams']                 NaN
# ...                                                ...                 ...
# 9821  ['Ishirô Honda', 'Jun Fukuda', 'Kengo Furusawa']  ['Kunio Miyauchi']
# 9822           ['Adriana Bosch', 'M Pink Christofalo']    ['Mason Daring']
# 9823                                     ['Matt Codd']  ['Richard McHugh']
# 9824                                 ['Robert Altman']  ['Van Dyke Parks']
# 9825                                ['John McTiernan']  ['Alan Silvestri']
#
#                                                  writer  runtime
# 0      ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1     ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...    125.0
# 2                                                   NaN     54.0
# 3                                                   NaN     85.0
# 4                 ['Katelyn Crabb', 'Kevin Williamson']      NaN
# ...                                                 ...      ...
# 9821                             ["Shin'ichi Sekizawa"]     69.0
# 9822                                  ['Adriana Bosch']      NaN
# 9823  ['Jonathan Raymond', 'Jonathan Raymond', 'Phil...     96.0
# 9824  ['Neve Campbell', 'Barbara Turner', 'Barbara T...    112.0
# 9825                      ['Jim Thomas', 'John Thomas']    107.0
#
# [9826 rows x 14 columns]>

# %%
# List of columns
df3.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'kind', 'genre', 'rating', 'vote',
#        'country', 'language', 'cast', 'director', 'composer', 'writer',
#        'runtime'],
#       dtype='object')

# %%
df3.kind.unique
# Out:
# <bound method Series.unique of 0       tv mini series
# 1                movie
# 2          video movie
# 3             tv movie
# 4                  NaN
#              ...
# 9821             movie
# 9822           episode
# 9823          tv movie
# 9824             movie
# 9825             movie
# Name: kind, Length: 9826, dtype: object>

# %%
null_values = df3.isnull().sum()
if null_values.any():
    print("Null values found:")
    print(null_values)
else:
    print("No null values found.")
# Out:
# Null values found:
# Unnamed: 0       0
# title            1
# year            70
# kind            38
# genre           93
# rating         877
# vote           877
# country        665
# language       793
# cast           344
# director      1860
# composer      3622
# writer        1656
# runtime       1056
# dtype: int64

# %%
duplicated_rows = df3.duplicated().sum()
if duplicated_rows:
    print(f"{duplicated_rows} duplicated rows found.")
else:
    print("No duplicated rows found.")
# Out:
# No duplicated rows found.

# %%
import pandas as pd
df3 = "C:/Users/ALEV PC/Desktop/Project/Data/raw/imdb.csv"
df3 = pd.read_csv(df3)

columns_to_delete = ['cast', 'director', 'composer', 'writer', 'runtime', 'Unnamed: 0']
df3 = df3.drop(columns=columns_to_delete)
display(df3)
# Out:
#                               title    year            kind  \
# 0                   Dinosaur Planet  2003.0  tv mini series
# 1                         Character  2021.0           movie
# 2                 Get Up and Dance!  1994.0     video movie
# 3     The Rise and Fall of El Chapo  2016.0        tv movie
# 4                       Sick - IMDb     NaN             NaN
# ...                             ...     ...             ...
# 9821            All Monsters Attack  1969.0           movie
# 9822                   Fidel Castro  2005.0         episode
# 9823                          Epoch  2001.0        tv movie
# 9824                    The Company  2003.0           movie
# 9825                       Predator  1987.0           movie
#
#                                               genre  rating      vote  \
# 0            ['Documentary', 'Animation', 'Family']     7.7     474.0
# 1                   ['Crime', 'Horror', 'Thriller']     8.3      46.0
# 2                                        ['Family']     8.1      18.0
# 3                                   ['Documentary']     6.9      42.0
# 4                                      ['Thriller']     NaN       NaN
# ...                                             ...     ...       ...
# 9821             ['Adventure', 'Family', 'Fantasy']     3.9    4384.0
# 9822        ['Documentary', 'Biography', 'History']     6.4      44.0
# 9823                         ['Sci-Fi', 'Thriller']     4.9    2376.0
# 9824                  ['Drama', 'Music', 'Romance']     6.3    6501.0
# 9825  ['Action', 'Adventure', 'Sci-Fi', 'Thriller']     7.8  386850.0
#
#                                              country  \
# 0                                  ['United States']
# 1                                          ['Japan']
# 2                                  ['United States']
# 3                                  ['United States']
# 4                                  ['United States']
# ...                                              ...
# 9821                                       ['Japan']
# 9822                                             NaN
# 9823                               ['United States']
# 9824  ['United States', 'Germany', 'United Kingdom']
# 9825                     ['United States', 'Mexico']
#
#                                language
# 0                           ['English']
# 1                          ['Japanese']
# 2                           ['English']
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 9821                       ['Japanese']
# 9822             ['English', 'Spanish']
# 9823                        ['English']
# 9824                        ['English']
# 9825  ['English', 'Spanish', 'Russian']
#
# [9826 rows x 8 columns]

# %%
df3 = df3.dropna()
display(df3)
# Out:
#                              title    year            kind  \
# 0                  Dinosaur Planet  2003.0  tv mini series
# 1                        Character  2021.0           movie
# 2                Get Up and Dance!  1994.0     video movie
# 5                            8 Man  1992.0           movie
# 6     What the #$*! Do We (K)now!?  2004.0           movie
# ...                            ...     ...             ...
# 9820           Shakespeare in Love  1998.0           movie
# 9821           All Monsters Attack  1969.0           movie
# 9823                         Epoch  2001.0        tv movie
# 9824                   The Company  2003.0           movie
# 9825                      Predator  1987.0           movie
#
#                                                   genre  rating      vote  \
# 0                ['Documentary', 'Animation', 'Family']     7.7     474.0
# 1                       ['Crime', 'Horror', 'Thriller']     8.3      46.0
# 2                                            ['Family']     8.1      18.0
# 5                                  ['Action', 'Sci-Fi']     5.5      93.0
# 6     ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3   13432.0
# ...                                                 ...     ...       ...
# 9820          ['Comedy', 'Drama', 'History', 'Romance']     7.1  218921.0
# 9821                 ['Adventure', 'Family', 'Fantasy']     3.9    4384.0
# 9823                             ['Sci-Fi', 'Thriller']     4.9    2376.0
# 9824                      ['Drama', 'Music', 'Romance']     6.3    6501.0
# 9825      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']     7.8  386850.0
#
#                                              country  \
# 0                                  ['United States']
# 1                                          ['Japan']
# 2                                  ['United States']
# 5                                          ['Japan']
# 6                                  ['United States']
# ...                                              ...
# 9820             ['United States', 'United Kingdom']
# 9821                                       ['Japan']
# 9823                               ['United States']
# 9824  ['United States', 'Germany', 'United Kingdom']
# 9825                     ['United States', 'Mexico']
#
#                                language
# 0                           ['English']
# 1                          ['Japanese']
# 2                           ['English']
# 5                          ['Japanese']
# 6      ['English', 'German', 'Spanish']
# ...                                 ...
# 9820                        ['English']
# 9821                       ['Japanese']
# 9823                        ['English']
# 9824                        ['English']
# 9825  ['English', 'Spanish', 'Russian']
#
# [8506 rows x 8 columns]

# %%
tv_movie = df3[df3["kind"] == "movie"]
tv_movie
# Out:
#                                                   title    year   kind  \
# 1                                             Character  2021.0  movie
# 5                                                 8 Man  1992.0  movie
# 6                          What the #$*! Do We (K)now!?  2004.0  movie
# 7     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0  movie
# 8                                           The Fighter  2010.0  movie
# ...                                                 ...     ...    ...
# 9819                                          Interiors  1978.0  movie
# 9820                                Shakespeare in Love  1998.0  movie
# 9821                                All Monsters Attack  1969.0  movie
# 9824                                        The Company  2003.0  movie
# 9825                                           Predator  1987.0  movie
#
#                                                   genre  rating      vote  \
# 1                       ['Crime', 'Horror', 'Thriller']     8.3      46.0
# 5                                  ['Action', 'Sci-Fi']     5.5      93.0
# 6     ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3   13432.0
# 7                        ['Comedy', 'Horror', 'Sci-Fi']     4.5    2177.0
# 8                       ['Biography', 'Drama', 'Sport']     7.8  351199.0
# ...                                                 ...     ...       ...
# 9819                                          ['Drama']     7.4   19143.0
# 9820          ['Comedy', 'Drama', 'History', 'Romance']     7.1  218921.0
# 9821                 ['Adventure', 'Family', 'Fantasy']     3.9    4384.0
# 9824                      ['Drama', 'Music', 'Romance']     6.3    6501.0
# 9825      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']     7.8  386850.0
#
#                                              country  \
# 1                                          ['Japan']
# 5                                          ['Japan']
# 6                                  ['United States']
# 7                                  ['United States']
# 8                                  ['United States']
# ...                                              ...
# 9819                               ['United States']
# 9820             ['United States', 'United Kingdom']
# 9821                                       ['Japan']
# 9824  ['United States', 'Germany', 'United Kingdom']
# 9825                     ['United States', 'Mexico']
#
#                                language
# 1                          ['Japanese']
# 5                          ['Japanese']
# 6      ['English', 'German', 'Spanish']
# 7                           ['English']
# 8                           ['English']
# ...                                 ...
# 9819                        ['English']
# 9820                        ['English']
# 9821                       ['Japanese']
# 9824                        ['English']
# 9825  ['English', 'Spanish', 'Russian']
#
# [5349 rows x 8 columns]

# %%
# Remove ".0" from the values in the "year" and "vote" columns
df3['year'] = df3['year'].astype(str).str.rstrip('.0')
df3['vote'] = df3['vote'].astype(str).str.rstrip('.0')
display(df3)

# Now df3 will contain all rows with ".0" removed from the "year" and "vote" columns
# Out:
#                              title  year            kind  \
# 0                  Dinosaur Planet  2003  tv mini series
# 1                        Character  2021           movie
# 2                Get Up and Dance!  1994     video movie
# 5                            8 Man  1992           movie
# 6     What the #$*! Do We (K)now!?  2004           movie
# ...                            ...   ...             ...
# 9820           Shakespeare in Love  1998           movie
# 9821           All Monsters Attack  1969           movie
# 9823                         Epoch  2001        tv movie
# 9824                   The Company  2003           movie
# 9825                      Predator  1987           movie
#
#                                                   genre rating    vote  \
# 0                ['Documentary', 'Animation', 'Family']    7.7     474
# 1                       ['Crime', 'Horror', 'Thriller']    8.3      46
# 2                                            ['Family']    8.1      18
# 5                                  ['Action', 'Sci-Fi']    5.5      93
# 6     ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...    5.3   13432
# ...                                                 ...    ...     ...
# 9820          ['Comedy', 'Drama', 'History', 'Romance']    7.1  218921
# 9821                 ['Adventure', 'Family', 'Fantasy']    3.9    4384
# 9823                             ['Sci-Fi', 'Thriller']    4.9    2376
# 9824                      ['Drama', 'Music', 'Romance']    6.3    6501
# 9825      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']    7.8   38685
#
#                                              country  \
# 0                                  ['United States']
# 1                                          ['Japan']
# 2                                  ['United States']
# 5                                          ['Japan']
# 6                                  ['United States']
# ...                                              ...
# 9820             ['United States', 'United Kingdom']
# 9821                                       ['Japan']
# 9823                               ['United States']
# 9824  ['United States', 'Germany', 'United Kingdom']
# 9825                     ['United States', 'Mexico']
#
#                                language
# 0                           ['English']
# 1                          ['Japanese']
# 2                           ['English']
# 5                          ['Japanese']
# 6      ['English', 'German', 'Spanish']
# ...                                 ...
# 9820                        ['English']
# 9821                       ['Japanese']
# 9823                        ['English']
# 9824                        ['English']
# 9825  ['English', 'Spanish', 'Russian']
#
# [8506 rows x 8 columns]

# %%
# Remove '[', ']', and ' ' from the values in country, language and genre columns
df3['country'] = df3['country'].str.replace('[\[\]\']', '', regex=True).str.strip()
df3['language'] = df3['language'].str.replace('[\[\]\']', '', regex=True).str.strip()
df3['genre'] = df3['genre'].str.replace('[\[\]\']', '', regex=True).str.strip()

display (df3)
# Out:
#                              title  year            kind  \
# 0                  Dinosaur Planet  2003  tv mini series
# 1                        Character  2021           movie
# 2                Get Up and Dance!  1994     video movie
# 5                            8 Man  1992           movie
# 6     What the #$*! Do We (K)now!?  2004           movie
# ...                            ...   ...             ...
# 9820           Shakespeare in Love  1998           movie
# 9821           All Monsters Attack  1969           movie
# 9823                         Epoch  2001        tv movie
# 9824                   The Company  2003           movie
# 9825                      Predator  1987           movie
#
#                                                   genre rating    vote  \
# 0                        Documentary, Animation, Family    7.7     474
# 1                               Crime, Horror, Thriller    8.3      46
# 2                                                Family    8.1      18
# 5                                        Action, Sci-Fi    5.5      93
# 6     Documentary, Comedy, Drama, Fantasy, Mystery, ...    5.3   13432
# ...                                                 ...    ...     ...
# 9820                    Comedy, Drama, History, Romance    7.1  218921
# 9821                         Adventure, Family, Fantasy    3.9    4384
# 9823                                   Sci-Fi, Thriller    4.9    2376
# 9824                              Drama, Music, Romance    6.3    6501
# 9825                Action, Adventure, Sci-Fi, Thriller    7.8   38685
#
#                                    country                 language
# 0                            United States                  English
# 1                                    Japan                 Japanese
# 2                            United States                  English
# 5                                    Japan                 Japanese
# 6                            United States   English,German,Spanish
# ...                                    ...                      ...
# 9820          United States,United Kingdom                  English
# 9821                                 Japan                 Japanese
# 9823                         United States                  English
# 9824  United States,Germany,United Kingdom                  English
# 9825                  United States,Mexico  English,Spanish,Russian
#
# [8506 rows x 8 columns]

# %%
df3['country'] = df3['country'].str.replace('UnitedStates', 'United States')
df3['country'] = df3['country'].str.replace('UnitedKingdom', 'United Kingdom')
display(df3)
# Out:
#                              title  year            kind  \
# 0                  Dinosaur Planet  2003  tv mini series
# 1                        Character  2021           movie
# 2                Get Up and Dance!  1994     video movie
# 5                            8 Man  1992           movie
# 6     What the #$*! Do We (K)now!?  2004           movie
# ...                            ...   ...             ...
# 9820           Shakespeare in Love  1998           movie
# 9821           All Monsters Attack  1969           movie
# 9823                         Epoch  2001        tv movie
# 9824                   The Company  2003           movie
# 9825                      Predator  1987           movie
#
#                                                   genre rating    vote  \
# 0                        Documentary, Animation, Family    7.7     474
# 1                               Crime, Horror, Thriller    8.3      46
# 2                                                Family    8.1      18
# 5                                        Action, Sci-Fi    5.5      93
# 6     Documentary, Comedy, Drama, Fantasy, Mystery, ...    5.3   13432
# ...                                                 ...    ...     ...
# 9820                    Comedy, Drama, History, Romance    7.1  218921
# 9821                         Adventure, Family, Fantasy    3.9    4384
# 9823                                   Sci-Fi, Thriller    4.9    2376
# 9824                              Drama, Music, Romance    6.3    6501
# 9825                Action, Adventure, Sci-Fi, Thriller    7.8   38685
#
#                                    country                 language
# 0                            United States                  English
# 1                                    Japan                 Japanese
# 2                            United States                  English
# 5                                    Japan                 Japanese
# 6                            United States   English,German,Spanish
# ...                                    ...                      ...
# 9820          United States,United Kingdom                  English
# 9821                                 Japan                 Japanese
# 9823                         United States                  English
# 9824  United States,Germany,United Kingdom                  English
# 9825                  United States,Mexico  English,Spanish,Russian
#
# [8506 rows x 8 columns]

# %%
df3 = df3.dropna(how='any')
display(df3)
# Out:
#                              title  year            kind  \
# 0                  Dinosaur Planet  2003  tv mini series
# 1                        Character  2021           movie
# 2                Get Up and Dance!  1994     video movie
# 5                            8 Man  1992           movie
# 6     What the #$*! Do We (K)now!?  2004           movie
# ...                            ...   ...             ...
# 9820           Shakespeare in Love  1998           movie
# 9821           All Monsters Attack  1969           movie
# 9823                         Epoch  2001        tv movie
# 9824                   The Company  2003           movie
# 9825                      Predator  1987           movie
#
#                                                   genre rating    vote  \
# 0                        Documentary, Animation, Family    7.7     474
# 1                               Crime, Horror, Thriller    8.3      46
# 2                                                Family    8.1      18
# 5                                        Action, Sci-Fi    5.5      93
# 6     Documentary, Comedy, Drama, Fantasy, Mystery, ...    5.3   13432
# ...                                                 ...    ...     ...
# 9820                    Comedy, Drama, History, Romance    7.1  218921
# 9821                         Adventure, Family, Fantasy    3.9    4384
# 9823                                   Sci-Fi, Thriller    4.9    2376
# 9824                              Drama, Music, Romance    6.3    6501
# 9825                Action, Adventure, Sci-Fi, Thriller    7.8   38685
#
#                                    country                 language
# 0                            United States                  English
# 1                                    Japan                 Japanese
# 2                            United States                  English
# 5                                    Japan                 Japanese
# 6                            United States   English,German,Spanish
# ...                                    ...                      ...
# 9820          United States,United Kingdom                  English
# 9821                                 Japan                 Japanese
# 9823                         United States                  English
# 9824  United States,Germany,United Kingdom                  English
# 9825                  United States,Mexico  English,Spanish,Russian
#
# [8506 rows x 8 columns]

# %%
df3.to_csv('C:/Users/ALEV PC/Desktop/Project/Data/cleaned/output.csv', index=False)
