# %%
# Data3 contains an updated version of Data2 including movies after 2005 to 2023.
# Row number indicates how many movies the data contains (+1 row 0)-> 9826
# Dataset url = https://www.kaggle.com/datasets/akashguna/netflix-prize-shows-information/data

# %%
# Main libraries : Pandas, Numpy, bs4
# Libraries for data visualisation : Matplotlib, Seaborn, Plotly

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objs as go

# %%
df3 = "C:/Users/ALEV PC/Desktop/Project/Data/raw/imdb.csv"
df3 = pd.read_csv(df3)
df3.head()
# Out:
#    Unnamed: 0                          title    year            kind  \
# 0           0                Dinosaur Planet  2003.0  tv mini series
# 1           1                      Character  2021.0           movie
# 2           2              Get Up and Dance!  1994.0     video movie
# 3           3  The Rise and Fall of El Chapo  2016.0        tv movie
# 4           4                    Sick - IMDb     NaN             NaN
#
#                                     genre  rating   vote            country  \
# 0  ['Documentary', 'Animation', 'Family']     7.7  474.0  ['United States']
# 1         ['Crime', 'Horror', 'Thriller']     8.3   46.0          ['Japan']
# 2                              ['Family']     8.1   18.0  ['United States']
# 3                         ['Documentary']     6.9   42.0  ['United States']
# 4                            ['Thriller']     NaN    NaN  ['United States']
#
#        language                                               cast  \
# 0   ['English']              ['Christian Slater', 'Scott Sampson']
# 1  ['Japanese']  ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# 2   ['English']  ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 3           NaN                                                NaN
# 4           NaN  ['Marc Menchaca', 'Gideon Adlon', 'Dylan Spray...
#
#             director          composer  \
# 0                NaN               NaN
# 1    ['Akira Nagai']  ['Youki Kojima']
# 2  ['Steve Purcell']               NaN
# 3                NaN               NaN
# 4     ['John Hyams']               NaN
#
#                                               writer  runtime
# 0   ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1  ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...    125.0
# 2                                                NaN     54.0
# 3                                                NaN     85.0
# 4              ['Katelyn Crabb', 'Kevin Williamson']      NaN

# %%
df3.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                          title    year            kind  \
# 0              0                Dinosaur Planet  2003.0  tv mini series
# 1              1                      Character  2021.0           movie
# 2              2              Get Up and Dance!  1994.0     video movie
# 3              3  The Rise and Fall of El Chapo  2016.0        tv movie
# 4              4                    Sick - IMDb     NaN             NaN
# ...          ...                            ...     ...             ...
# 9821        9821            All Monsters Attack  1969.0           movie
# 9822        9822                   Fidel Castro  2005.0         episode
# 9823        9823                          Epoch  2001.0        tv movie
# 9824        9824                    The Company  2003.0           movie
# 9825        9825                       Predator  1987.0           movie
#
#                                               genre  rating      vote  \
# 0            ['Documentary', 'Animation', 'Family']     7.7     474.0
# 1                   ['Crime', 'Horror', 'Thriller']     8.3      46.0
# 2                                        ['Family']     8.1      18.0
# 3                                   ['Documentary']     6.9      42.0
# 4                                      ['Thriller']     NaN       NaN
# ...                                             ...     ...       ...
# 9821             ['Adventure', 'Family', 'Fantasy']     3.9    4384.0
# 9822        ['Documentary', 'Biography', 'History']     6.4      44.0
# 9823                         ['Sci-Fi', 'Thriller']     4.9    2376.0
# 9824                  ['Drama', 'Music', 'Romance']     6.3    6501.0
# 9825  ['Action', 'Adventure', 'Sci-Fi', 'Thriller']     7.8  386850.0
#
#                                              country  \
# 0                                  ['United States']
# 1                                          ['Japan']
# 2                                  ['United States']
# 3                                  ['United States']
# 4                                  ['United States']
# ...                                              ...
# 9821                                       ['Japan']
# 9822                                             NaN
# 9823                               ['United States']
# 9824  ['United States', 'Germany', 'United Kingdom']
# 9825                     ['United States', 'Mexico']
#
#                                language  \
# 0                           ['English']
# 1                          ['Japanese']
# 2                           ['English']
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 9821                       ['Japanese']
# 9822             ['English', 'Spanish']
# 9823                        ['English']
# 9824                        ['English']
# 9825  ['English', 'Spanish', 'Russian']
#
#                                                    cast  \
# 0                 ['Christian Slater', 'Scott Sampson']
# 1     ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# 2     ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 3                                                   NaN
# 4     ['Marc Menchaca', 'Gideon Adlon', 'Dylan Spray...
# ...                                                 ...
# 9821  ['Tomonori Yazaki', 'Hideyo Amamoto', 'Sachio ...
# 9822  ['Rena Baskin', 'Fulgencio Batista', 'James Bl...
# 9823  ['David Keith', 'Stephanie Niznik', "Ryan O'Ne...
# 9824  ['Neve Campbell', 'Malcolm McDowell', 'James F...
# 9825  ['Arnold Schwarzenegger', 'Carl Weathers', 'El...
#
#                                               director            composer  \
# 0                                                  NaN                 NaN
# 1                                      ['Akira Nagai']    ['Youki Kojima']
# 2                                    ['Steve Purcell']                 NaN
# 3                                                  NaN                 NaN
# 4                                       ['John Hyams']                 NaN
# ...                                                ...                 ...
# 9821  ['Ishirô Honda', 'Jun Fukuda', 'Kengo Furusawa']  ['Kunio Miyauchi']
# 9822           ['Adriana Bosch', 'M Pink Christofalo']    ['Mason Daring']
# 9823                                     ['Matt Codd']  ['Richard McHugh']
# 9824                                 ['Robert Altman']  ['Van Dyke Parks']
# 9825                                ['John McTiernan']  ['Alan Silvestri']
#
#                                                  writer  runtime
# 0      ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1     ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...    125.0
# 2                                                   NaN     54.0
# 3                                                   NaN     85.0
# 4                 ['Katelyn Crabb', 'Kevin Williamson']      NaN
# ...                                                 ...      ...
# 9821                             ["Shin'ichi Sekizawa"]     69.0
# 9822                                  ['Adriana Bosch']      NaN
# 9823  ['Jonathan Raymond', 'Jonathan Raymond', 'Phil...     96.0
# 9824  ['Neve Campbell', 'Barbara Turner', 'Barbara T...    112.0
# 9825                      ['Jim Thomas', 'John Thomas']    107.0
#
# [9826 rows x 14 columns]>

# %%
# List of columns
df3.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'kind', 'genre', 'rating', 'vote',
#        'country', 'language', 'cast', 'director', 'composer', 'writer',
#        'runtime'],
#       dtype='object')

# %%
df3.kind.unique
# Out:
# <bound method Series.unique of 0       tv mini series
# 1                movie
# 2          video movie
# 3             tv movie
# 4                  NaN
#              ...
# 9821             movie
# 9822           episode
# 9823          tv movie
# 9824             movie
# 9825             movie
# Name: kind, Length: 9826, dtype: object>

# %%
tv_movie = df3[df3["kind"] == "movie"]
tv_movie
# Out:
#       Unnamed: 0                                              title    year  \
# 1              1                                          Character  2021.0
# 5              5                                              8 Man  1992.0
# 6              6                       What the #$*! Do We (K)now!?  2004.0
# 7              7  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0
# 8              8                                        The Fighter  2010.0
# ...          ...                                                ...     ...
# 9819        9819                                          Interiors  1978.0
# 9820        9820                                Shakespeare in Love  1998.0
# 9821        9821                                All Monsters Attack  1969.0
# 9824        9824                                        The Company  2003.0
# 9825        9825                                           Predator  1987.0
#
#        kind                                              genre  rating  \
# 1     movie                    ['Crime', 'Horror', 'Thriller']     8.3
# 5     movie                               ['Action', 'Sci-Fi']     5.5
# 6     movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 7     movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
# 8     movie                    ['Biography', 'Drama', 'Sport']     7.8
# ...     ...                                                ...     ...
# 9819  movie                                          ['Drama']     7.4
# 9820  movie          ['Comedy', 'Drama', 'History', 'Romance']     7.1
# 9821  movie                 ['Adventure', 'Family', 'Fantasy']     3.9
# 9824  movie                      ['Drama', 'Music', 'Romance']     6.3
# 9825  movie      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']     7.8
#
#           vote                                         country  \
# 1         46.0                                       ['Japan']
# 5         93.0                                       ['Japan']
# 6      13432.0                               ['United States']
# 7       2177.0                               ['United States']
# 8     351199.0                               ['United States']
# ...        ...                                             ...
# 9819   19143.0                               ['United States']
# 9820  218921.0             ['United States', 'United Kingdom']
# 9821    4384.0                                       ['Japan']
# 9824    6501.0  ['United States', 'Germany', 'United Kingdom']
# 9825  386850.0                     ['United States', 'Mexico']
#
#                                language  \
# 1                          ['Japanese']
# 5                          ['Japanese']
# 6      ['English', 'German', 'Spanish']
# 7                           ['English']
# 8                           ['English']
# ...                                 ...
# 9819                        ['English']
# 9820                        ['English']
# 9821                       ['Japanese']
# 9824                        ['English']
# 9825  ['English', 'Spanish', 'Russian']
#
#                                                    cast  \
# 1     ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# 5     ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 6     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 7     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# 8     ['Mark Wahlberg', 'Christian Bale', 'Amy Adams...
# ...                                                 ...
# 9819  ['Kristin Griffith', 'Mary Beth Hurt', 'Richar...
# 9820  ['Geoffrey Rush', 'Tom Wilkinson', "Steven O'D...
# 9821  ['Tomonori Yazaki', 'Hideyo Amamoto', 'Sachio ...
# 9824  ['Neve Campbell', 'Malcolm McDowell', 'James F...
# 9825  ['Arnold Schwarzenegger', 'Carl Weathers', 'El...
#
#                                                director  \
# 1                                       ['Akira Nagai']
# 5                                 ['Yasuhiro Horiuchi']
# 6     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 7                                       ['Eric Louzil']
# 8                                  ['David O. Russell']
# ...                                                 ...
# 9819                                    ['Woody Allen']
# 9820                                    ['John Madden']
# 9821   ['Ishirô Honda', 'Jun Fukuda', 'Kengo Furusawa']
# 9824                                  ['Robert Altman']
# 9825                                 ['John McTiernan']
#
#                     composer  \
# 1           ['Youki Kojima']
# 5            ['Carole King']
# 6     ['Christopher Franke']
# 7            ['Bob Mithoff']
# 8          ['Michael Brook']
# ...                      ...
# 9819                     NaN
# 9820     ['Stephen Warbeck']
# 9821      ['Kunio Miyauchi']
# 9824      ['Van Dyke Parks']
# 9825      ['Alan Silvestri']
#
#                                                  writer  runtime
# 1     ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...    125.0
# 5     ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']     83.0
# 6     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...    109.0
# 7        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# 8       ['Scott Silver', 'Paul Tamasy', 'Eric Johnson']    116.0
# ...                                                 ...      ...
# 9819                                    ['Woody Allen']     92.0
# 9820                    ['Marc Norman', 'Tom Stoppard']    123.0
# 9821                             ["Shin'ichi Sekizawa"]     69.0
# 9824  ['Neve Campbell', 'Barbara Turner', 'Barbara T...    112.0
# 9825                      ['Jim Thomas', 'John Thomas']    107.0
#
# [5541 rows x 14 columns]

# %%
null_values = df3.isnull().sum()
if null_values.any():
    print("Null values found:")
    print(null_values)
else:
    print("No null values found.")
# Out:
# Null values found:
# Unnamed: 0       0
# title            1
# year            70
# kind            38
# genre           93
# rating         877
# vote           877
# country        665
# language       793
# cast           344
# director      1860
# composer      3622
# writer        1656
# runtime       1056
# dtype: int64

# %%
duplicated_rows = df3.duplicated().sum()
if duplicated_rows:
    print(f"{duplicated_rows} duplicated rows found.")
else:
    print("No duplicated rows found.")
# Out:
# No duplicated rows found.

# %%
df3 = df3 [["title","year","kind" , "country", "genre" ]]
df3
# Out:
#                               title    year            kind  \
# 0                   Dinosaur Planet  2003.0  tv mini series
# 1                         Character  2021.0           movie
# 2                 Get Up and Dance!  1994.0     video movie
# 3     The Rise and Fall of El Chapo  2016.0        tv movie
# 4                       Sick - IMDb     NaN             NaN
# ...                             ...     ...             ...
# 9821            All Monsters Attack  1969.0           movie
# 9822                   Fidel Castro  2005.0         episode
# 9823                          Epoch  2001.0        tv movie
# 9824                    The Company  2003.0           movie
# 9825                       Predator  1987.0           movie
#
#                                              country  \
# 0                                  ['United States']
# 1                                          ['Japan']
# 2                                  ['United States']
# 3                                  ['United States']
# 4                                  ['United States']
# ...                                              ...
# 9821                                       ['Japan']
# 9822                                             NaN
# 9823                               ['United States']
# 9824  ['United States', 'Germany', 'United Kingdom']
# 9825                     ['United States', 'Mexico']
#
#                                               genre
# 0            ['Documentary', 'Animation', 'Family']
# 1                   ['Crime', 'Horror', 'Thriller']
# 2                                        ['Family']
# 3                                   ['Documentary']
# 4                                      ['Thriller']
# ...                                             ...
# 9821             ['Adventure', 'Family', 'Fantasy']
# 9822        ['Documentary', 'Biography', 'History']
# 9823                         ['Sci-Fi', 'Thriller']
# 9824                  ['Drama', 'Music', 'Romance']
# 9825  ['Action', 'Adventure', 'Sci-Fi', 'Thriller']
#
# [9826 rows x 5 columns]

# %%
df3.country.info
# Out:
# <bound method Series.info of 0                                    ['United States']
# 1                                            ['Japan']
# 2                                    ['United States']
# 3                                    ['United States']
# 4                                    ['United States']
#                              ...
# 9821                                         ['Japan']
# 9822                                               NaN
# 9823                                 ['United States']
# 9824    ['United States', 'Germany', 'United Kingdom']
# 9825                       ['United States', 'Mexico']
# Name: country, Length: 9826, dtype: object>
