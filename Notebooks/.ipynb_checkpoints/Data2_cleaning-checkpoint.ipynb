# %%
# Data2 is a scrapped data from IMDB, contains movies from 1905 to 2005

# %%
# Main libraries : Pandas, Numpy, bs4a
# Libraries for data visualisation : Matplotlib, Seaborn, Plotly

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go

# %%
df2 = "C:/Users/ALEV PC/Desktop/Project/Data/raw/imdb_processed.csv"
df2 = pd.read_csv(df2)
df2.head()
# Out:
#    Unnamed: 0                                              title    year  \
# 0           0                                    Dinosaur Planet  2003.0
# 1           1                                  Get Up and Dance!  1994.0
# 2           2                                              8 Man  1992.0
# 3           3                       What the #$*! Do We (K)now!?  2004.0
# 4           4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0
#
#              kind                                              genre  rating  \
# 0  tv mini series             ['Documentary', 'Animation', 'Family']     7.7
# 1     video movie                                         ['Family']     8.1
# 2           movie                               ['Action', 'Sci-Fi']     5.5
# 3           movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4           movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
#
# ...

# %%
df2.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                                              title    year  \
# 0              0                                    Dinosaur Planet  2003.0
# 1              1                                  Get Up and Dance!  1994.0
# 2              2                                              8 Man  1992.0
# 3              3                       What the #$*! Do We (K)now!?  2004.0
# 4              4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0
# ...          ...                                                ...     ...
# 8446        8446                                All Monsters Attack  1969.0
# 8447        8447                                       Fidel Castro  2005.0
# 8448        8448                                              Epoch  2001.0
# 8449        8449                                        The Company  2003.0
# 8450        8450                                           Predator  1987.0
#
# ...

# %%
# List of columns
df2.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'kind', 'genre', 'rating', 'vote',
#        'country', 'language', 'cast', 'director', 'composer', 'writer',
#        'runtime'],
#       dtype='object')

# %%
# The irrelevant columns: "Unnamed: 0", "cast", "director", "composer", "writer", "runtime"

# %%
# Countries - to be separated "United States" and others. The other countries will be examanied - which ones have bigger proportion
# Languages - to be separated "English" and others. The other languages will be examanied - which ones have bigger proportion
# Comedy / drama ratio - For the decades - Data contains years between 1905 to 2023. 
# 
#
#

# %%
null_values = df2.isnull().sum()
if null_values.any():
    print("Null values found:")
    print(null_values)
else:
    print("No null values found.")
# Out:
# Null values found:
# Unnamed: 0       0
# title            0
# year             0
# kind             0
# genre           67
# rating         316
# vote           316
# country        299
# language       399
# cast           171
# director      1311
# composer      2729
# writer        1247
# runtime       1653
# dtype: int64

# %%
duplicated_rows = df2.duplicated().sum()
if duplicated_rows:
    print(f"{duplicated_rows} duplicated rows found.")
else:
    print("No duplicated rows found.")
# Out:
# No duplicated rows found.

# %%
column_name = 'year'

# Sort the year in ascending order
df2_sorted = df2.sort_values(by="year", ascending=True)

display(df2_sorted)
# Out:
#       Unnamed: 0                                              title    year  \
# 3472        3472  Battalion of Seaforth Highlanders at the Dubli...  1905.0
# 8055        8055  Battalion of Seaforth Highlanders at the Dubli...  1905.0
# 232          232  Battalion of Seaforth Highlanders at the Dubli...  1905.0
# 8434        8434  Battalion of Seaforth Highlanders at the Dubli...  1905.0
# 270          270  Battalion of Seaforth Highlanders at the Dubli...  1905.0
# ...          ...                                                ...     ...
# 7952        7952                                   Super Bowl XXXIX  2005.0
# 976          976                               A Chinese Tall Story  2005.0
# 987          987                                The Fearless Freaks  2005.0
# 2490        2490               Phil of the Future: Gadgets & Gizmos  2005.0
# 6414        6414                                        Rock School  2005.0
#
# ...
